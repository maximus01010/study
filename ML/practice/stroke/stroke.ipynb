# %%
import csv
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/sasidharreddy/study/ML/practice/stroke/stroke.csv',delimiter=',')
print(df['stroke'])
X = np.array([row[:-1] for row in df])
y = np.array([row[-1] for row in df])
X_train, X_test, y_train, y_test = df.split(X, y, test_size=0.2, random_state=42)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7516/701694352.py in ?()
#       1 df = pd.read_csv('/home/sasidharreddy/study/ML/practice/stroke/stroke.csv',delimiter=',')
#       2 print(df['stroke'])
#       3 X = np.array([row[:-1] for row in df])
#       4 y = np.array([row[-1] for row in df])
# ----> 5 X_train, X_test, y_train, y_test = df.split(X, y, test_size=0.2, random_state=42)
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in ?(self, name)
#    5483             and name not in self._accessors
#    5484             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485         ):
#    5486             return self[name]
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Sample data with three features and binary output
data = [
    [1, 2, 3, 0],
    [4, 5, 6, 1],
    [7, 8, 9, 0],
    [10, 11, 12, 1],
    [13, 14, 15, 0]
]

# Separate features and labels
features = [row[:-1] for row in data]
labels = [row[-1] for row in data]

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with color-coded labels
ax.scatter([feat[0] for feat in features], [feat[1] for feat in features], [feat[2] for feat in features], c=labels, marker='o')

# Set axis labels
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')

plt.title('3D Scatter Plot with Binary Output')
plt.show()
